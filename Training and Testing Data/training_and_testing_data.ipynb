# %% [markdown]
# Training Dataset
# The training data is the biggest (in -size) subset of the original dataset, which is used to train or fit the machine learning model.
#
# Test Datset
# The test dataset is another subset of original data, which is independent of the training dataset.

# %% [markdown]
# Training and Testing Available Data
# We have a dataset containing prices of used BMW cars. We are going to analyze this dataset and build a prediction function that can predict a price by taking mileage and age of the car as input. We will use sklearn train_test_split method to split training and testing dataset

# %%
import pandas as pd
df = pd.read_csv("carprices.csv")
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Prices($)
# 0    69000         6           18000
# 1    35000         3           34000
# 2    57000         5           26100
# 3    22500         2           40000
# 4    46000         4           31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Car Mileage Vs Sell Price($)

# %%
plt.scatter(df['Mileage'], df['Sell Prices($)'])

# %% [markdown]
# Car Age Vs Sell Price($)

# %%
plt.scatter(df['Age(yrs)'], df['Sell Prices($)'])

# %% [markdown]
# Looking at above two scatter plots, using linear regression model makes sense as we can clearly see a linear relationship between our dependent (i.e. Sell Price) and independent variables (i.e. car age and car mileage)

# %% [markdown]
# The approach we are going to use here is to split available data in two sets
#
# 1. Training: We will train our model on this dataset
# 2. Testing: We will use this subset to make actual predictions using trained model
#
# The reason we don't use same training set for testing is because our model has seen those samples before, using same samples for making predictions might give us wrong impression about accuracy of our model. It is like you ask same questions in exam paper as you tought the students in the class.

# %%
x = df[['Mileage', 'Age(yrs)']]

# %%
y = df['Sell Prices($)']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train
# Out:
#     Mileage  Age(yrs)
# 14    82450         7
# 11    79000         7
# 0     69000         6
# 8     91000         8
# 9     67000         6
# 1     35000         3
# 5     59500         5
# 12    59000         5
# 7     72000         6
# 10    83000         7
# 18    87600         8
# 3     22500         2
# 2     57000         5
# 13    58780         4
# 17    69000         5
# 4     46000         4

# %%
x_test
# Out:
#     Mileage  Age(yrs)
# 6     52000         5
# 15    25400         3
# 16    28000         2
# 19    52000         5

# %%
y_train
# Out:
# 14    19400
# 11    19500
# 0     18000
# 8     12000
# 9     22000
# 1     34000
# 5     26750
# 12    26000
# 7     19300
# 10    18700
# 18    12800
# 3     40000
# 2     26100
# 13    27500
# 17    19700
# 4     31500
# Name: Sell Prices($), dtype: int64

# %%
y_test
# Out:
# 6     32000
# 15    35000
# 16    35500
# 19    28200
# Name: Sell Prices($), dtype: int64

# %% [markdown]
# Lets run linear regression model now

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([27898.76594183, 37996.92171121, 37810.87590418, 27898.76594183])

# %%
x_test
# Out:
#     Mileage  Age(yrs)
# 6     52000         5
# 15    25400         3
# 16    28000         2
# 19    52000         5

# %%
y_test
# Out:
# 6     32000
# 15    35000
# 16    35500
# 19    28200
# Name: Sell Prices($), dtype: int64

# %%
clf.score(x_test, y_test)
# Out:
# 0.07780172893290005

# %% [markdown]
# random_state argument

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=10)
x_test
# Out:
#     Mileage  Age(yrs)
# 7     72000         6
# 10    83000         7
# 5     59500         5
# 6     52000         5
# 3     22500         2
# 18    87600         8
